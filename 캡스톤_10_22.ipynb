# %% [markdown]
# <a href="https://colab.research.google.com/github/Skyofwhite/TeamFroze/blob/main/%EC%BA%A1%EC%8A%A4%ED%86%A4_10_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16013, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 16013 (delta 25), reused 23 (delta 13), pack-reused 15967
# Receiving objects: 100% (16013/16013), 14.60 MiB | 28.53 MiB/s, done.
# Resolving deltas: 100% (10991/10991), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 27.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.7 MB/s eta 0:00:00

# %%
# %mkdir /content/dataset
# %cd /content/dataset

# 데이터셋 다운
#!curl -L "https://universe.roboflow.com/ds/1EZ8xi3zFi?key=GCJOlbNzGe" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
#!curl -L "https://universe.roboflow.com/ds/WoROGe0e8B?key=CTTUDTB6r0" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# !curl -L "https://universe.roboflow.com/ds/6H7TeTqtS8?key=3iyv287OeH" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
#!curl -L "https://universe.roboflow.com/ds/QzNjSqBVYM?key=aHJLvjRAlB" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: valid/images/DSC_5842_JPG_jpg.rf.7fec9b249913f342b8e924e1e2377da0.jpg
#  extracting: valid/images/DSC_5842_JPG_jpg.rf.9716590dca1cda4458ee94c170a56045.jpg
#  extracting: valid/images/DSC_5842_JPG_jpg.rf.9a141eea99ea3354aac238ef662d667a.jpg
#  extracting: valid/images/DSC_5842_JPG_jpg.rf.9e4e59d9e48e503696abf39c28175b80.jpg
#  extracting: valid/images/DSC_5843_JPG_jpg.rf.8e5b3d40007467857c1b59fcd7ce7056.jpg
#  extracting: valid/images/DSC_5846_JPG_jpg.rf.3770ec60b30067a8b75e59d7886272be.jpg
#  extracting: valid/images/DSC_5846_JPG_jpg.rf.4a8a0a276d1a5da50d77a659aac4da81.jpg
#  extracting: valid/images/DSC_5846_JPG_jpg.rf.653d147eac8e59813cfad7dfc4cdfa3a.jpg
#  extracting: valid/images/DSC_5846_JPG_jpg.rf.70845bdc2f13a3c0ba5500d178bb7469.jpg
#  extracting: valid/images/DSC_5846_JPG_jpg.rf.7c9aac903137f98aba19e01de78cc5ab.jpg
#  extracting: valid/images/DSC_5846_JPG_jpg.rf.8e8d124509dc3ea0bce4018c002d35c9.jpg
# ...

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
import yaml

with open("/content/dataset/data.yaml", 'r') as f:
  data = yaml.load(f, Loader=yaml.FullLoader)

data['train'] = "/content/dataset/"
data['test'] = "/content/dataset/"
data['val'] = "/content/dataset/"

with open("/content/dataset/data.yaml", 'w') as f:
  yaml.dump(data, f)

# %%
# %cd /root/.config/Ultralytics/
# Out:
# [Errno 2] No such file or directory: '/root/.config/Ultralytics/'
# /content/yolov5

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-7ce124cc-e7df-4331-8110-8e4ba402e848" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ce124cc-e7df-4331-8110-8e4ba402e848">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --data "/content/dataset/data.yaml" --epochs 30 --batch 16
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/dataset/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-228-g4d687c8 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# ...

# %%
# !python val.py --data "/content/dataset/data.yaml" --weights "/content/yolov5/runs/train/exp/weights/best.pt"
# Out:
# val: data=/content/dataset/data.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-228-g4d687c8 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7196218 parameters, 0 gradients, 16.3 GFLOPs
# val: Scanning /content/dataset/test/labels.cache... 6792 images, 48 backgrounds, 0 corrupt: 100% 6792/6792 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 213/213 [01:06<00:00,  3.19it/s]
#                    all       6792      49177      0.895      0.693      0.798      0.543
# ...

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp/weights/best.pt" --source "/content/dataset/test/images/"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/dataset/test/images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-228-g4d687c8 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7196218 parameters, 0 gradients, 16.3 GFLOPs
# image 1/681 /content/dataset/test/images/1685517783983_jpg.rf.cb4a1e1622773cfb0cddd9cc6f913377.jpg: 640x640 1 Onion, 1 Shallot, 1 Sweetcorn, 1 carrot, 1 chicken, 4 cream cheeses, 5.8ms
# ...

# %%
import cv2
import matplotlib.pyplot as plt
from glob import glob

img_paths = glob("runs/detect/exp/*")

plt.figure(figsize=(16, 10))
plt.subplot(1,3,1)
plt.imshow(cv2.imread(img_paths[0]))
plt.subplot(1,3,2)
plt.imshow(cv2.imread(img_paths[1]))
plt.subplot(1,3,3)
plt.imshow(cv2.imread(img_paths[2]))
plt.show()
